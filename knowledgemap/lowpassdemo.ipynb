# %%
import numpy as np
import matplotlib.pyplot as plt

# Set the dimensions for the image (e.g., 256x256 pixels)
width, height = 256, 256

# Generate a 2D array of random values between 0 and 1
white_noise = np.random.rand(height, width) - 0.5

# Compute the 2D Fourier transform of the image
frequency_content = np.fft.fft2(white_noise)
frequency_content_shifted = np.fft.fftshift(frequency_content)  # Shift zero frequency to center

# Calculate the magnitude spectrum (log scale for better visualization)
magnitude_spectrum = np.abs(frequency_content_shifted) + 1 # Adding 1 to avoid log(0)

# Plot the original white noise image and its frequency spectrum
fig, axes = plt.subplots(1, 2, figsize=(10, 5))

# Original white noise image
axes[0].imshow(white_noise, cmap='gray')
axes[0].set_title("White Noise Image")
axes[0].axis('off')  # Hide axes

# Frequency spectrum
axes[1].imshow(magnitude_spectrum, cmap='gray')
axes[1].set_title("Magnitude Spectrum")
axes[1].axis('off')  # Hide axes

plt.show()

r_bin = np.arange(0, r.max(), 1)  # Radial bins
radial_profile = np.zeros_like(r_bin, dtype=np.float32)

for i in range(len(r_bin) - 1):
    mask = (r >= r_bin[i]) & (r < r_bin[i + 1])
    radial_profile[i] = magnitude_spectrum[mask].mean()

# Plot the 1D radial frequency spectrum
plt.plot(r_bin[:-1], radial_profile[:-1])
plt.xlabel("Frequency (radial)")
plt.ylabel("Magnitude")
plt.title("1D Radial Frequency Spectrum of White Noise")
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.ndimage import gaussian_filter

# Set the dimensions for the image (e.g., 256x256 pixels)
width, height = 256, 256

# Generate a 2D array of random values between 0 and 1 and subtract the mean
white_noise = np.random.rand(height, width) - 0.5

# Apply Gaussian smoothing to the white noise
smoothed_noise = gaussian_filter(white_noise, sigma=5)  # Adjust sigma for different smoothing levels

# Compute the 2D Fourier transform of the smoothed image
frequency_content = np.fft.fft2(smoothed_noise)
frequency_content_shifted = np.fft.fftshift(frequency_content)  # Shift zero frequency to center

# Calculate the magnitude spectrum (log scale for better visualization)
magnitude_spectrum = np.log(np.abs(frequency_content_shifted) + 1)  # Adding 1 to avoid log(0)

# Plot the smoothed white noise image and its frequency spectrum
fig, axes = plt.subplots(1, 2, figsize=(10, 5))

# Smoothed white noise image
axes[0].imshow(smoothed_noise, cmap='gray')
axes[0].set_title("Smoothed White Noise Image")
axes[0].axis('off')  # Hide axes

# Frequency spectrum
axes[1].imshow(magnitude_spectrum, cmap='gray')
axes[1].set_title("Magnitude Spectrum after Smoothing")
axes[1].axis('off')  # Hide axes

plt.show()

# Create coordinates for the radial bins
y, x = np.indices(magnitude_spectrum.shape)
center = (x.max() / 2, y.max() / 2)
r = np.sqrt((x - center[0])**2 + (y - center[1])**2).astype(int)

# Calculate the radial profile
r_bin = np.arange(0, r.max(), 1)  # Radial bins
radial_profile = np.zeros_like(r_bin, dtype=np.float32)

for i in range(len(r_bin) - 1):
    mask = (r >= r_bin[i]) & (r < r_bin[i + 1])
    radial_profile[i] = magnitude_spectrum[mask].mean()

# Plot the 1D radial frequency spectrum after smoothing
plt.plot(r_bin[:-1], radial_profile[:-1])
plt.xlabel("Frequency (radial)")
plt.ylabel("Magnitude")
plt.title("1D Radial Frequency Spectrum after Gaussian Smoothing")
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.ndimage import gaussian_filter

# Set the dimensions for the image (e.g., 256x256 pixels)
width, height = 256, 256

# Generate a 2D array of random values between 0 and 1 and subtract the mean
white_noise = np.random.rand(height, width) - 0.5

# Apply Gaussian smoothing to the white noise
smoothed_noise = gaussian_filter(white_noise, sigma=10)  # Adjust sigma for different smoothing levels

# Compute the 2D Fourier transform of the smoothed image
frequency_content = np.fft.fft2(smoothed_noise)
frequency_content_shifted = np.fft.fftshift(frequency_content)  # Shift zero frequency to center

# Calculate the magnitude spectrum (log scale for better visualization)
magnitude_spectrum = np.log(np.abs(frequency_content_shifted) + 1)  # Adding 1 to avoid log(0)

# Plot the smoothed white noise image and its frequency spectrum
fig, axes = plt.subplots(1, 2, figsize=(10, 5))

# Smoothed white noise image
axes[0].imshow(smoothed_noise, cmap='gray')
axes[0].set_title("Smoothed White Noise Image")
axes[0].axis('off')  # Hide axes

# Frequency spectrum
axes[1].imshow(magnitude_spectrum, cmap='gray')
axes[1].set_title("Magnitude Spectrum after Smoothing")
axes[1].axis('off')  # Hide axes

plt.show()

# Create coordinates for the radial bins
y, x = np.indices(magnitude_spectrum.shape)
center = (x.max() / 2, y.max() / 2)
r = np.sqrt((x - center[0])**2 + (y - center[1])**2).astype(int)

# Calculate the radial profile
r_bin = np.arange(0, r.max(), 1)  # Radial bins
radial_profile = np.zeros_like(r_bin, dtype=np.float32)

for i in range(len(r_bin) - 1):
    mask = (r >= r_bin[i]) & (r < r_bin[i + 1])
    radial_profile[i] = magnitude_spectrum[mask].mean()

# Plot the 1D radial frequency spectrum after smoothing
plt.plot(r_bin[:-1], radial_profile[:-1])
plt.xlabel("Frequency (radial)")
plt.ylabel("Magnitude")
plt.title("1D Radial Frequency Spectrum after Gaussian Smoothing")
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.ndimage import gaussian_filter

# Set the dimensions for the image (e.g., 256x256 pixels)
width, height = 256, 256

# Generate a 2D array of random values between 0 and 1 and subtract the mean
white_noise = np.random.rand(height, width) - 0.5

# Apply Gaussian smoothing to the white noise
smoothed_noise = gaussian_filter(white_noise, sigma=1)  # Adjust sigma for different smoothing levels

# Compute the 2D Fourier transform of the smoothed image
frequency_content = np.fft.fft2(smoothed_noise)
frequency_content_shifted = np.fft.fftshift(frequency_content)  # Shift zero frequency to center

# Calculate the magnitude spectrum (log scale for better visualization)
magnitude_spectrum = np.log(np.abs(frequency_content_shifted) + 1)  # Adding 1 to avoid log(0)

# Plot the smoothed white noise image and its frequency spectrum
fig, axes = plt.subplots(1, 2, figsize=(10, 5))

# Smoothed white noise image
axes[0].imshow(smoothed_noise, cmap='gray')
axes[0].set_title("Smoothed White Noise Image")
axes[0].axis('off')  # Hide axes

# Frequency spectrum
axes[1].imshow(magnitude_spectrum, cmap='gray')
axes[1].set_title("Magnitude Spectrum after Smoothing")
axes[1].axis('off')  # Hide axes

plt.show()

# Create coordinates for the radial bins
y, x = np.indices(magnitude_spectrum.shape)
center = (x.max() / 2, y.max() / 2)
r = np.sqrt((x - center[0])**2 + (y - center[1])**2).astype(int)

# Calculate the radial profile
r_bin = np.arange(0, r.max(), 1)  # Radial bins
radial_profile = np.zeros_like(r_bin, dtype=np.float32)

for i in range(len(r_bin) - 1):
    mask = (r >= r_bin[i]) & (r < r_bin[i + 1])
    radial_profile[i] = magnitude_spectrum[mask].mean()

# Plot the 1D radial frequency spectrum after smoothing
plt.plot(r_bin[:-1], radial_profile[:-1])
plt.xlabel("Frequency (radial)")
plt.ylabel("Magnitude")
plt.title("1D Radial Frequency Spectrum after Gaussian Smoothing")
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.ndimage import gaussian_filter

# Set the dimensions for the image (e.g., 256x256 pixels)
width, height = 256, 256

# Generate a 2D array of random values between 0 and 1 and subtract the mean
white_noise = np.random.rand(height, width) - 0.5

# Apply Gaussian smoothing to the white noise
smoothed_noise = gaussian_filter(white_noise, sigma=1)  # Adjust sigma for different smoothing levels
smoothed_noise = white_noise - smoothed_noise
# Compute the 2D Fourier transform of the smoothed image
frequency_content = np.fft.fft2(smoothed_noise)
frequency_content_shifted = np.fft.fftshift(frequency_content)  # Shift zero frequency to center

# Calculate the magnitude spectrum (log scale for better visualization)
magnitude_spectrum = np.log(np.abs(frequency_content_shifted) + 1)  # Adding 1 to avoid log(0)

# Plot the smoothed white noise image and its frequency spectrum
fig, axes = plt.subplots(1, 2, figsize=(10, 5))

# Smoothed white noise image
axes[0].imshow(smoothed_noise, cmap='gray')
axes[0].set_title("Smoothed White Noise Image")
axes[0].axis('off')  # Hide axes

# Frequency spectrum
axes[1].imshow(magnitude_spectrum, cmap='gray')
axes[1].set_title("Magnitude Spectrum after Smoothing")
axes[1].axis('off')  # Hide axes

plt.show()

# Create coordinates for the radial bins
y, x = np.indices(magnitude_spectrum.shape)
center = (x.max() / 2, y.max() / 2)
r = np.sqrt((x - center[0])**2 + (y - center[1])**2).astype(int)

# Calculate the radial profile
r_bin = np.arange(0, r.max(), 1)  # Radial bins
radial_profile = np.zeros_like(r_bin, dtype=np.float32)

for i in range(len(r_bin) - 1):
    mask = (r >= r_bin[i]) & (r < r_bin[i + 1])
    radial_profile[i] = magnitude_spectrum[mask].mean()

# Plot the 1D radial frequency spectrum after smoothing
plt.plot(r_bin[:-1], radial_profile[:-1])
plt.xlabel("Frequency (radial)")
plt.ylabel("Magnitude")
plt.title("1D Radial Frequency Spectrum after Gaussian Smoothing")
plt.show()

# %% [markdown]
# # Function

# %%
import numpy as np
import matplotlib.pyplot as plt

width, height = 256, 256
white_noise = np.random.rand(height, width) - 0.5

def get_spectrum(image):
    frequency_content = np.fft.fft2(image)
    frequency_content_shifted = np.fft.fftshift(frequency_content)
    magnitude_spectrum = np.log(np.abs(frequency_content_shifted) + 1)
    y, x = np.indices(magnitude_spectrum.shape)
    center = (x.max() / 2, y.max() / 2)
    r = np.sqrt((x - center[0])**2 + (y - center[1])**2).astype(int)
    r_bin = np.arange(0, r.max(), 1)
    radial_profile = np.zeros_like(r_bin, dtype=np.float32)

    for i in range(len(r_bin) - 1):
        mask = (r >= r_bin[i]) & (r < r_bin[i + 1])
        radial_profile[i] = magnitude_spectrum[mask].mean()
        
    return radial_profile

plt.plot(get_spectrum(white_noise))

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.ndimage import gaussian_filter

# Set the dimensions for the image (e.g., 256x256 pixels)
width, height = 256, 256

# Generate a 2D array of random values between 0 and 1 and subtract the mean
white_noise = np.random.rand(height, width) - 0.5

# Apply Gaussian smoothing to the white noise
smoothed_noise = gaussian_filter(white_noise, sigma=1)  # Adjust sigma for different smoothing levels
smoothed_noise = white_noise - smoothed_noise
# Compute the 2D Fourier transform of the smoothed image
frequency_content = np.fft.fft2(smoothed_noise)
frequency_content_shifted = np.fft.fftshift(frequency_content)  # Shift zero frequency to center

# Calculate the magnitude spectrum (log scale for better visualization)
magnitude_spectrum = np.abs(frequency_content_shifted) + 1  # Adding 1 to avoid log(0)

# Plot the smoothed white noise image and its frequency spectrum
fig, axes = plt.subplots(1, 2, figsize=(10, 5))

# Smoothed white noise image
axes[0].imshow(smoothed_noise, cmap='gray')
axes[0].set_title("Smoothed White Noise Image")
axes[0].axis('off')  # Hide axes

# Frequency spectrum
axes[1].imshow(magnitude_spectrum, cmap='gray')
axes[1].set_title("Magnitude Spectrum after Smoothing")
axes[1].axis('off')  # Hide axes

plt.show()

# Create coordinates for the radial bins
y, x = np.indices(magnitude_spectrum.shape)
center = (x.max() / 2, y.max() / 2)
r = np.sqrt((x - center[0])**2 + (y - center[1])**2).astype(int)

# Calculate the radial profile
r_bin = np.arange(0, r.max(), 1)  # Radial bins
radial_profile = np.zeros_like(r_bin, dtype=np.float32)

for i in range(len(r_bin) - 1):
    mask = (r >= r_bin[i]) & (r < r_bin[i + 1])
    radial_profile[i] = magnitude_spectrum[mask].mean()

# Plot the 1D radial frequency spectrum after smoothing
plt.plot(r_bin[:-1], radial_profile[:-1])
plt.xlabel("Frequency (radial)")
plt.ylabel("Magnitude")
plt.title("1D Radial Frequency Spectrum after Gaussian Smoothing")
plt.show()

# %% [markdown]
# # 11/8/2024
